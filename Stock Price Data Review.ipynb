# %%
import pandas as pd
import pandas_datareader as web
import datetime
import matplotlib.pyplot as plt
import numpy as np

# %%
# We will look at stock prices over the past year, starting at January 1, 2019
start = datetime.datetime(2019,7,1)
end = datetime.date.today()

# %%
# Let's get Apple stock data; Apple's ticker symbol is AAPL
# First argument is the series we want, second is the source ("yahoo" for Yahoo! Finance), third is the start date, fourth is the end date
apple = web.DataReader("AAPL", "yahoo", start, end)
amazon = web.DataReader("Amzn", "yahoo", start, end)
alibaba = web.DataReader("BABA", "yahoo", start, end)
type(apple)
# Out:
# pandas.core.frame.DataFrame

# %%
apple.head(5)
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2019-07-01  204.490005  200.649994  203.169998  201.550003  27253000.0
# 2019-07-02  203.130005  201.360001  201.410004  202.729996  16935200.0
# 2019-07-03  204.440002  202.690002  203.279999  204.410004  11362000.0
# 2019-07-05  205.080002  202.899994  203.350006  204.229996  17265500.0
# 2019-07-08  201.399994  198.410004  200.809998  200.020004  25338600.0
#
#              Adj Close
# Date
# 2019-07-01  200.787125
# 2019-07-02  201.962646
# 2019-07-03  203.636292
# 2019-07-05  203.456970
# 2019-07-08  199.262909

# %%
# %matplotlib inline
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pylab.rcParams['figure.figsize'] = (15, 5)   # Change the size of plots

# %%
# Below I create a DataFrame consisting of the adjusted closing price of these stocks, first by making a list of these objects and using the join method
stocks = pd.DataFrame({"AAPL": apple ["Adj Close"],
                      "AMZN": amazon["Adj Close"],
                      "BABA": alibaba["Adj Close"]})
stocks.head()
# Out:
#                   AAPL         AMZN        BABA
# Date
# 2019-07-01  200.787125  1922.189941  175.050003
# 2019-07-02  201.962646  1934.310059  175.449997
# 2019-07-03  203.636292  1939.000000  174.669998
# 2019-07-05  203.456970  1942.910034  173.300003
# 2019-07-08  199.262909  1952.319946  168.449997

# %%
stocks
# Out:
#                   AAPL         AMZN        BABA
# Date
# 2019-07-01  200.787125  1922.189941  175.050003
# 2019-07-02  201.962646  1934.310059  175.449997
# 2019-07-03  203.636292  1939.000000  174.669998
# 2019-07-05  203.456970  1942.910034  173.300003
# 2019-07-08  199.262909  1952.319946  168.449997
# 2019-07-09  200.478302  1988.300049  168.800003
# 2019-07-10  202.460754  2017.410034  166.929993
# 2019-07-11  200.986359  2001.069946  166.550003
# 2019-07-12  202.530502  2011.000000  169.070007
# 2019-07-15  204.433273  2020.989990  173.500000
# 2019-07-16  203.725952  2009.900024  174.190002
# 2019-07-17  202.580307  1992.030029  174.820007
# 2019-07-18  204.881561  1977.900024  172.800003
# 2019-07-19  201.823181  1964.520020  172.990005
# 2019-07-22  206.435654  1985.630005  174.000000
# 2019-07-23  208.049515  1994.489990  178.089996
# 2019-07-24  207.880173  2000.810059  178.669998
# 2019-07-25  206.236420  1973.819946  177.289993
# ...

# %%
apple["Adj Close"].plot(grid = True) # Plot the adjusted closing price of AAPL

# %%
stocks.plot(grid = True)

# %%
stocks.plot(secondary_y = [ "AAPL","BABA"], grid = True)
